# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree

df=pd.read_csv('Dataset.csv')

#Level 2: Data Integrity Audit

#Missing data is filled with mode of the respective fields. Mode seems the most appropriate as all datas are discrete and limited in range.
df=df.fillna({
    'famsize': df['famsize'].mode()[0],
    'Fedu': df['Fedu'].mode()[0],
    'traveltime': df['traveltime'].mode()[0],
    'higher': df['higher'].mode()[0],
    'freetime': df['freetime'].mode()[0],
    'absences': df['absences'].mode()[0],
    'G2': df['G2'].mode()[0],
    'Feature_1': df['Feature_1'].mode()[0],
    'Feature_2': df['Feature_2'].mode()[0],
    'Feature_3': df['Feature_3'].mode()[0]
})
# Level 1: Variable Identification Protocol

# Feature_1: 

freq=df.groupby(['Feature_1','school']).size().unstack()
print(freq)

sns.countplot(data=df, x='Feature_1', hue='school')

plt.xlabel('Feature_1')
plt.ylabel('Count')
plt.title('Frequency of school by Feature_1')
plt.show()

freq=df.groupby(['Feature_1','sex']).size().unstack()
print(freq)

sns.countplot(data=df, x='Feature_1', hue='sex')

plt.xlabel('Feature_1')
plt.ylabel('Count')
plt.title('Frequency of Gender by Feature_1')
plt.show()

freq=df.groupby(['Feature_1','internet']).size().unstack()
print(freq)

sns.countplot(data=df, x='Feature_1', hue='internet')

plt.xlabel('Feature_1')
plt.ylabel('Count')
plt.title('Frequency of internet by Feature_1')
plt.show()

freq=df.groupby(['Feature_1','traveltime']).size().unstack()
print(freq)

sns.countplot(data=df, x='Feature_1', hue='traveltime')

plt.xlabel('Feature_1')
plt.ylabel('Count')
plt.title('Frequency of traveltime by Feature_1')
plt.show()

freq=df.groupby(['Feature_1','health']).size().unstack()
print(freq)

sns.countplot(data=df, x='Feature_1', hue='health')

plt.xlabel('Feature_1')
plt.ylabel('Count')
plt.title('Frequency of health by Feature_1')
plt.show()

freq=df.groupby(['Feature_1','G3']).size().unstack()
print(freq)

sns.countplot(data=df, x='Feature_1', hue='G3')

plt.xlabel('Feature_1')
plt.ylabel('Count')
plt.title('Frequency of G3 by Feature_1')
plt.show()

freq=df.groupby(['Feature_1','romantic']).size().unstack()
print(freq)

sns.countplot(data=df, x='Feature_1', hue='romantic')

plt.xlabel('Feature_1')
plt.ylabel('Count')
plt.title('Frequency of romantic by Feature_1')
plt.show()

freq=df.groupby(['Feature_1','activities']).size().unstack()
print(freq)

sns.countplot(data=df, x='Feature_1', hue='activities')

plt.xlabel('Feature_1')
plt.ylabel('Count')
plt.title('Frequency of activities by Feature_1')
plt.show()
#Conclusion: Since the distribution is similar to normal for most categories, Feature_1 seems to be performance in a competitive indoor sport which doesn't 
#require much of an intellectual capability, for eg carrom

#Feature 2:

freq=df.groupby(['Feature_2','school']).size().unstack()
print(freq)

sns.countplot(data=df, x='Feature_2', hue='school')

plt.xlabel('Feature_2')
plt.ylabel('Count')
plt.title('Frequency of school by Feature_2')
plt.show()

freq=df.groupby(['Feature_2','sex']).size().unstack()
print(freq)

sns.countplot(data=df, x='Feature_2', hue='sex')

plt.xlabel('Feature_2')
plt.ylabel('Count')
plt.title('Frequency of Gender by Feature_2')
plt.show()

freq=df.groupby(['Feature_2','internet']).size().unstack()
print(freq)

sns.countplot(data=df, x='Feature_2', hue='internet')

plt.xlabel('Feature_2')
plt.ylabel('Count')
plt.title('Frequency of internet by Feature_2')
plt.show()

freq=df.groupby(['Feature_2','traveltime']).size().unstack()
print(freq)

sns.countplot(data=df, x='Feature_2', hue='traveltime')

plt.xlabel('Feature_2')
plt.ylabel('Count')
plt.title('Frequency of traveltime by Feature_2')
plt.show()

freq=df.groupby(['Feature_2','health']).size().unstack()
print(freq)

sns.countplot(data=df, x='Feature_2', hue='health')

plt.xlabel('Feature_2')
plt.ylabel('Count')
plt.title('Frequency of health by Feature_2')
plt.show()

freq=df.groupby(['G3','Feature_2']).size().unstack()
print(freq)

sns.countplot(data=df, x='G3', hue='Feature_2')

plt.xlabel('G3')
plt.ylabel('Count')
plt.title('Frequency of Feature_2 by G3')
plt.show()

freq=df.groupby(['Feature_2','romantic']).size().unstack()
print(freq)

sns.countplot(data=df, x='Feature_2', hue='romantic')

plt.xlabel('Feature_2')
plt.ylabel('Count')
plt.title('Frequency of romantic by Feature_2')
plt.show()

freq=df.groupby(['Feature_2','activities']).size().unstack()
print(freq)

sns.countplot(data=df, x='Feature_2', hue='activities')

plt.xlabel('Feature_2')
plt.ylabel('Count')
plt.title('Frequency of activities by Feature_2')
plt.show()
#Conclusion: Graphs are similar to Feature_1 but the gender graph is similar to normal distribution for girls but slightly right skewed for boys. This could
#represent discipline index with 1 as worst, 2 as average, 3 as good and 4 as excellent.

#Feature_3

freq=df.groupby(['Feature_3','school']).size().unstack()
print(freq)

sns.countplot(data=df, x='Feature_3', hue='school')

plt.xlabel('Feature_3')
plt.ylabel('Count')
plt.title('Frequency of school by Feature_3')
plt.show()

freq=df.groupby(['Feature_3','sex']).size().unstack()
print(freq)

sns.countplot(data=df, x='Feature_3', hue='sex')

plt.xlabel('Feature_3')
plt.ylabel('Count')
plt.title('Frequency of Gender by Feature_3')
plt.show()

freq=df.groupby(['Feature_3','internet']).size().unstack()
print(freq)

sns.countplot(data=df, x='Feature_3', hue='internet')

plt.xlabel('Feature_3')
plt.ylabel('Count')
plt.title('Frequency of internet by Feature_3')
plt.show()

freq=df.groupby(['Feature_3','traveltime']).size().unstack()
print(freq)

sns.countplot(data=df, x='Feature_3', hue='traveltime')

plt.xlabel('Feature_3')
plt.ylabel('Count')
plt.title('Frequency of traveltime by Feature_3')
plt.show()

freq=df.groupby(['Feature_3','health']).size().unstack()
print(freq)

sns.countplot(data=df, x='Feature_3', hue='health')

plt.xlabel('Feature_3')
plt.ylabel('Count')
plt.title('Frequency of health by Feature_3')
plt.show()

freq=df.groupby(['G3','Feature_3']).size().unstack()
print(freq)

sns.countplot(data=df, x='G3', hue='Feature_3')

plt.xlabel('G3')
plt.ylabel('Count')
plt.title('Frequency of Feature_3 by G3')
plt.show()

freq=df.groupby(['Feature_3','romantic']).size().unstack()
print(freq)

sns.countplot(data=df, x='Feature_3', hue='romantic')

plt.xlabel('Feature_3')
plt.ylabel('Count')
plt.title('Frequency of romantic by Feature_3')
plt.show()

freq=df.groupby(['Feature_3','activities']).size().unstack()
print(freq)

sns.countplot(data=df, x='Feature_3', hue='activities')

plt.xlabel('Feature_3')
plt.ylabel('Count')
plt.title('Frequency of activities by Feature_3')
plt.show()

freq=df.groupby(['Feature_3','paid']).size().unstack()
print(freq)

sns.countplot(data=df, x='Feature_3', hue='paid')

plt.xlabel('Feature_3')
plt.ylabel('Count')
plt.title('Frequency of paid by Feature_3')
plt.show()

#Conclusion: Since most of the distributions are right-skewed except for the pupils who go to paid tution classes- this suggests that feature_3 may represent 
#family income


# Level 3: Exploratory Insight Report   

#Q1: Does the parental cohabitation status affect the grades of students?

freq=df.groupby(['G3','Pstatus']).size().unstack()
print(freq)

sns.countplot(data=df, x='G3', hue='Pstatus')

plt.xlabel('G3')
plt.ylabel('Count')
plt.title('Frequency of Pstatus by Grades')
plt.show()
#Conclusion: It does not have much relation as ratios of T/A for most of the grades do not differ much

#Q2: Does type of school affect the grades of students?

freq=df.groupby(['G3','school']).size().unstack()
print(freq)

sns.countplot(data=df, x='G3', hue='school')

plt.xlabel('G3')
plt.ylabel('Count')
plt.title('Frequency of school by Grades')
plt.show()
#Conclusion: Performance of students at GP is better as more students with higher grades are there

#Q3: Does participation in extracurricular activities affect grades of students?

freq=df.groupby(['G3','activities']).size().unstack()
print(freq)

sns.countplot(data=df, x='G3', hue='activities')

plt.xlabel('G3')
plt.ylabel('Count')
plt.title('Frequency of activities by Grades')
plt.show()
#Conclusion: Students with better grades are also involved more in extra-cirruculars

#Q4: Does parental cohabitation status have an affect on family relationships?

freq=df.groupby(['Pstatus','famrel']).size().unstack()
print(freq)

sns.countplot(data=df, x='famrel', hue='Pstatus')

plt.xlabel('famrel')
plt.ylabel('Count')
plt.title('Pstatus by famrel')
plt.show()
#Conclusion: It does not affect as the ratio of people with same famrel in both types of Pstatus are similar

#Q5: Does size of family depend on address?

freq=df.groupby(['address','famsize']).size().unstack()
print(freq)

sns.countplot(data=df, x='address', hue='famsize')

plt.xlabel('address')
plt.ylabel('Count')
plt.title('Frequency of famsize by address')
plt.show()
#Conclusion: It does not depend on address as the percentage of LE3 and GT3 are almost similar for both urban and rural

plt.figure(figsize=(15, 8))
#Q6: Does health affect absences?

freq=df.groupby(['absences','health']).size().unstack()
print(freq)

sns.countplot(data=df, x='absences', hue='health')

plt.xlabel('absences')
plt.ylabel('Count')
plt.title('Frequency of health by absences')
plt.show()
#Conclusion: Better the health, fewer the absences

#Q7: Does more freetime lead to more hangouts with friends?

freq=df.groupby(['freetime','goout']).size().unstack()
print(freq)

sns.countplot(data=df, x='freetime', hue='goout')

plt.xlabel('freetime')
plt.ylabel('Count')
plt.title('Frequency of freetime by goout')
plt.show()
#Conclusion: There is not a strict correlation implying students maybe utilising their freetime somewhere else instead of hanging out with friends

#Q8: Does weekday alcohol consumption affect absences?

plt.figure(figsize=(15, 8))
freq=df.groupby(['absences','Dalc']).size().unstack()
print(freq)

sns.countplot(data=df, x='absences', hue='Dalc')

plt.xlabel('absences')
plt.ylabel('Count')
plt.title('Frequency of Dalc by absences')
plt.show()
#Conclusion: There is not a strict correlation for students with 1-4 Dalc but for students at extreme(Dalc=5), higher ratio of absences can be seen


#Level 4: Relationship Prediction Model

#Frequency of gender by school
freq = df.groupby(['school', 'sex']).size().unstack()
print(freq)

sns.countplot(data=df, x='school', hue='sex')

plt.xlabel('School')
plt.ylabel('Count')
plt.title('Frequency of Gender by School')
plt.show()
#Conclusion: F/M ratio is higher in MS


#Frequency of relationship by School
freq2=df.groupby(['school','romantic']).size().unstack()
print(freq2)

sns.countplot(data=df, x='school', hue='romantic')

plt.xlabel('School')
plt.ylabel('Count')
plt.title('Frequency of relationship by School')
plt.show()
#Conclusion: Ratio of Number of people in relationship is higher in MS

#Conclusion1: Higher F/M ratio favours higher ratio of people in relationship


#Frequency of relationship by Pstatus
freq3=df.groupby(['Pstatus','romantic']).size().unstack()
print(freq3)

sns.countplot(data=df, x='Pstatus', hue='romantic')

plt.xlabel('Pstatus')
plt.ylabel('Count')
plt.title('Frequency of relationship by Pstatus')
plt.show()
#Conclusion2: The ratio of people in relationship is higher for students whose parents are apart

#Frequency of relationship by failures
freq4=df.groupby(['failures','romantic']).size().unstack()
print(freq4)

sns.countplot(data=df, x='failures', hue='romantic')

plt.xlabel('failures')
plt.ylabel('Count')
plt.title('Frequency of relationship by failures')
plt.show()
#Conclusion3: The ratio of people in relationship generally increases with increase in number of failures

#Frequency of relationship by G3
freq5=df.groupby(['G3','romantic']).size().unstack()
print(freq5)

sns.countplot(data=df, x='G3', hue='romantic')

plt.xlabel('G3')
plt.ylabel('Count')
plt.title('Frequency of relationship by G3')
plt.show()
#Conclusion4: The ratio of people in relationships is lower for highest grades and higher for lowest grades but in general, doesn't follow a pattern

x=df.drop('romantic',axis=1)
y=df['romantic']

from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

categorical_features=["school","sex","address","famsize","Pstatus","Medu","Fedu","Mjob","Fjob","reason","guardian","traveltime","failures","schoolsup","famsup","paid","activities","nursery","higher","internet","famrel","freetime","goout","Dalc","health","absences","G1","G2","G3","Feature_1","Feature_2","Feature_3"]
one_hot=OneHotEncoder()
transformer=ColumnTransformer([("one_hot",
                                one_hot,
                                categorical_features)],
                                remainder="passthrough")

transformed_x=transformer.fit_transform(x)

x_train,x_test,y_train,y_test=train_test_split(transformed_x,y,test_size=0.2,random_state=100)
clf_entropy=DecisionTreeClassifier(criterion="entropy",random_state=100,max_depth=1,min_samples_leaf=6)
clf_entropy.fit(x_train,y_train)

y_pred_en=clf_entropy.predict(x_test)

accuracy_score(y_test,y_pred_en)
#This model predicts with accuracy of 66.92%

#Level 5: Model Reasoning & Interpretation
plt.rcParams['figure.figsize'] = (10.0, 8.0)

x_graph = df[['sex', 'Pstatus']].copy()
x_graph['sex'] = x_graph['sex'].map({'M': 0, 'F': 1})
x_graph['Pstatus'] = x_graph['Pstatus'].map({'A': 0, 'P': 1})
clf4 = DecisionTreeClassifier()
clf4.fit(x_graph, y)  

DecisionBoundaryDisplay.from_estimator(clf4, x_graph, cmap=plt.cm.RdYlBu)
plt.title("Decision Tree")
plt.xlabel('sex')
plt.ylabel('Pstatus')
plt.show()
# Out:
# school        GP    MS
# Feature_1
# 15.0        79.0  24.0
# 16.0       105.0  64.0
# 17.0       140.0  68.0
# 18.0        76.0  54.0
# 19.0        16.0  14.0
# 20.0         4.0   2.0
# 21.0         2.0   NaN
# 22.0         1.0   NaN
# sex            F     M
# Feature_1
# 15.0        54.0  49.0
# 16.0       102.0  67.0
# 17.0       126.0  82.0
# 18.0        78.0  52.0
# 19.0        18.0  12.0
# 20.0         4.0   2.0
# 21.0         1.0   1.0
# 22.0         NaN   1.0
# internet     no    yes
# Feature_1
# 15.0       21.0   82.0
# 16.0       44.0  125.0
# 17.0       51.0  157.0
# 18.0       25.0  105.0
# 19.0        9.0   21.0
# 20.0        1.0    5.0
# 21.0        NaN    2.0
# 22.0        NaN    1.0
# traveltime    1.0   2.0   3.0  4.0
# Feature_1
# 15.0         67.0  26.0   7.0  3.0
# 16.0        105.0  44.0  15.0  5.0
# 17.0        126.0  66.0  12.0  4.0
# 18.0         73.0  45.0  10.0  2.0
# 19.0         19.0   8.0   3.0  NaN
# 20.0          1.0   5.0   NaN  NaN
# ...
